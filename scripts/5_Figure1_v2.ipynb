# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as pe
from matplotlib.gridspec import GridSpec
from scipy.interpolate import griddata
from scipy.spatial import ConvexHull
from scipy.stats import gaussian_kde

# -----------------------------
# 1) Load data
# -----------------------------
csv_path = "/Users/xabajian/Documents/GitHub/ACF_NK_Measurement/simulations/bias_rmse.csv"
df = pd.read_csv(csv_path)

x = df["corr_N1_K_out"].to_numpy(float)
y = df["corr_N1_N2_out"].to_numpy(float)
z = df["RMSE_reduction_topcode"].to_numpy(float)

mask = np.isfinite(x) & np.isfinite(y) & np.isfinite(z)
x, y, z = x[mask], y[mask], z[mask]
iso_codes = df.loc[mask, "country_string"].values

# -----------------------------
# 2) Even grid
# -----------------------------
grid_min, grid_max, step = -0.5, 0.5, 0.01
xi = np.arange(grid_min, grid_max + 1e-12, step)
yi = np.arange(grid_min, grid_max + 1e-12, step)
X, Y = np.meshgrid(xi, yi)

Z_linear = griddata((x, y), z, (X, Y), method="linear")

# -----------------------------
# 3) Layout (flatter marginals)
# -----------------------------
fig = plt.figure(figsize=(8.6, 7.6))
gs = GridSpec(
    2, 2,
    width_ratios=[0.75, 4.0],
    height_ratios=[4.0, 0.75],
    hspace=0.05,
    wspace=0.05
)

ax_left   = fig.add_subplot(gs[0, 0])
ax_joint  = fig.add_subplot(gs[0, 1], sharey=ax_left)
ax_bottom = fig.add_subplot(gs[1, 1], sharex=ax_joint)

ax_corner = fig.add_subplot(gs[1, 0])
ax_corner.axis("off")

# -----------------------------
# 4) Main contour plot
# -----------------------------
cf = ax_joint.contourf(X, Y, Z_linear, levels=60)
ax_joint.contour(X, Y, Z_linear, levels=12, linewidths=0.6)

cbar = fig.colorbar(cf, ax=ax_joint, pad=0.02)
cbar.set_label("Reduction in RMSE", fontsize=12)

sf = ticker.ScalarFormatter(useMathText=True)
sf.set_scientific(True)
sf.set_powerlimits((0, 0))
cbar.formatter = sf
cbar.update_ticks()

# ISO labels
for xi0, yi0, label in zip(x, y, iso_codes):
    ax_joint.text(
        xi0, yi0, label,
        color="red", fontsize=7,
        ha="center", va="center",
        path_effects=[pe.withStroke(linewidth=1.5, foreground="white")]
    )

# Convex hull
pts = np.c_[x, y]
hull = ConvexHull(pts)
hull_xy = pts[hull.vertices]
hull_xy = np.vstack([hull_xy, hull_xy[0]])
ax_joint.plot(
    hull_xy[:, 0], hull_xy[:, 1],
    linestyle="--", linewidth=1.5,
    color="grey", alpha=0.9
)

ax_joint.set_xlim(grid_min, grid_max)
ax_joint.set_ylim(grid_min, grid_max)

# Remove duplicate labels on contour
ax_joint.set_xlabel("")
ax_joint.set_ylabel("")
ax_joint.tick_params(axis="x", labelbottom=False)
ax_joint.tick_params(axis="y", labelleft=False)

# -----------------------------
# 5) Marginals: hist + KDE
# -----------------------------
bins = 25
hist_face = "steelblue"
hist_edge = "navy"
kde_color = "orange"

label_fs = 7  # very small font for "Number of countries"

# Bottom histogram (x)
counts_x, edges_x, _ = ax_bottom.hist(
    x, bins=bins, range=(grid_min, grid_max),
    color=hist_face, alpha=0.8,
    edgecolor=hist_edge, linewidth=0.7
)

binw_x = edges_x[1] - edges_x[0]
x_grid = np.linspace(grid_min, grid_max, 400)
kde_x = gaussian_kde(x)
ax_bottom.plot(
    x_grid,
    kde_x(x_grid) * len(x) * binw_x,
    color=kde_color,
    linestyle="--",
    linewidth=2
)

ax_bottom.set_xlabel(r"$\rho(g_{N_1}, g_{K})$")
ax_bottom.set_ylabel("Number of \n countries", fontsize=label_fs)
ax_bottom.set_xlim(grid_min, grid_max)

# Left histogram (y)
counts_y, edges_y, _ = ax_left.hist(
    y, bins=bins, range=(grid_min, grid_max),
    orientation="horizontal",
    color=hist_face, alpha=0.8,
    edgecolor=hist_edge, linewidth=0.7
)

binw_y = edges_y[1] - edges_y[0]
y_grid = np.linspace(grid_min, grid_max, 400)
kde_y = gaussian_kde(y)
ax_left.plot(
    kde_y(y_grid) * len(y) * binw_y,
    y_grid,
    color=kde_color,
    linestyle="--",
    linewidth=2
)

ax_left.set_ylabel(r"$\rho(g_{N_1}, g_{N_2})$")
ax_left.set_xlabel("Number of \n countries", fontsize=label_fs)
ax_left.set_ylim(grid_min, grid_max)

# -----------------------------
# Final layout (DO THIS FIRST)
# -----------------------------
fig.subplots_adjust(left=0.08, right=0.96, bottom=0.08, top=0.96)

# -----------------------------
# MANUAL WIDTH ALIGNMENT FIX (DO THIS LAST)
# -----------------------------
fig.canvas.draw()  # finalize positions after subplots_adjust + colorbar

pos_joint = ax_joint.get_position()
pos_bottom = ax_bottom.get_position()

# Force bottom histogram plotting area to match contour plotting area exactly
ax_bottom.set_position([
    pos_joint.x0,         # same left edge as contour
    pos_bottom.y0,        # keep its vertical placement
    pos_joint.width,      # same width as contour (this is the key)
    pos_bottom.height
])

fig.canvas.draw()  # redraw with the new imposed geometry

# Save/show (only once)
fig.savefig("rmse_reduction_final_aligned.pdf", bbox_inches="tight")
plt.show()
